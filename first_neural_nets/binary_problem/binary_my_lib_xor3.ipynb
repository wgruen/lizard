# %% [markdown]
# # run locial problems with the libray I wrote

# %%
# !wget -O mount_gdrive.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb

#!ls
# %run mount_gdrive.ipynb
# Out:
# --2022-01-17 14:26:09--  https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10889 (11K) [text/plain]
# Saving to: ‘mount_gdrive.ipynb’
#
# mount_gdrive.ipynb  100%[===================>]  10.63K  --.-KB/s    in 0s
#
# 2022-01-17 14:26:09 (81.6 MB/s) - ‘mount_gdrive.ipynb’ saved [10889/10889]
#
# Mounted at /content/drive
# drive  mount_gdrive.ipynb  sample_data
# /content
# physical devises
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Mon Jan 17 14:26:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
# run python code
exit()  # exit runtime, so it restarts the runtime session


# !wget -O get_gpu.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/get_gpu.ipynb

#!ls
#!cat mount_gdrive.ipynb
# %run get_gpu.ipynb

# how to ensrue a GPU is usd by tf?
#tf. config. list_physical_devices('GPU')

# %cd "/content/drive/MyDrive/colab_wolfs_git_clones/lizard"
# !ls 
# !pwd

# %cd "first_neural_nets/binary_problem"
# !ls
# !pwd

# !pip install reportlab
# %run train_machine.py -i logical_xor3.configuration.yaml
# %run run_machine.py -i logical_xor3.configuration.yaml
# Out:
# --2022-01-17 14:26:30--  https://raw.githubusercontent.com/wgruen/lizard/master/get_gpu.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10864 (11K) [text/plain]
# Saving to: ‘get_gpu.ipynb’
#
# get_gpu.ipynb       100%[===================>]  10.61K  --.-KB/s    in 0s
#
# 2022-01-17 14:26:30 (87.2 MB/s) - ‘get_gpu.ipynb’ saved [10864/10864]
#
# physical devises
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Mon Jan 17 14:26:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    27W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Found GPU at: /device:GPU:0
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# diff.log	   get_tpu.ipynb       picture_problem
# first_neural_nets  mount_gdrive.ipynb  README.md
# get_gpu.ipynb	   nmf		       statistical_analysis
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# binary_my_lib_or3.ipynb		 logical_xor3.configuration.yaml
# binary_my_lib_xor3.ipynb	 logical_xor3.data.train.cvs
# binary_problem.py		 logical_xor3.data.validate.cvs
# logical_or2.data.validate.cvs	 logical_xor3.trained.machine.bin
# logical_or3.configuration.yaml	 output
# logical_or3.data.train.cvs	 __pycache__
# logical_or3.data.validate.cvs	 README.md
# logical_or3.trained.machine.bin  run_machine.py
# logical_or.trained.machine.bin	 train_machine.py
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# Collecting reportlab
#   Downloading reportlab-3.6.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 7.9 MB/s
# Requirement already satisfied: pillow>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from reportlab) (7.1.2)
# Installing collected packages: reportlab
# Successfully installed reportlab-3.6.5
# pwd: /content/drive/My Drive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# Namespace(input_config_file='logical_xor3.configuration.yaml')
# Input file name: logical_xor3.data.train.cvs
# Raw training_set_inputs: ****************
# [[0.04 0.03 0.1  0.02]
#  [0.04 0.03 0.98 0.94]
#  [0.04 0.98 0.03 0.97]
#  [0.98 0.04 0.02 0.96]
#  [0.98 0.97 0.98 0.01]]
# training_set_inputs: ****************
# [[0.04 0.03 0.1 ]
#  [0.04 0.03 0.98]
#  [0.04 0.98 0.03]
#  [0.98 0.04 0.02]
#  [0.98 0.97 0.98]]
# training_set_outputs: ****************
# [[0.02]
#  [0.94]
#  [0.97]
#  [0.96]
#  [0.01]]
#
#
#
#
# weights holder:
# [   array([999, 999, 999]),
#     array([[0.94361564, 0.73412622, 0.41378177],
#        [0.97850434, 0.01474545, 0.73027366],
#        [0.59925636, 0.96945344, 0.78151866],
#        [0.23273011, 0.83903569, 0.10063323],
#        [0.52737497, 0.03831846, 0.61428659],
#        [0.96128135, 0.50637904, 0.13681026]]),
#     array([[0.63238175, 0.49235124, 0.94056071, 0.95752905, 0.38554488,
#         0.41267111]])]
#
# Value holder:
# [array([999, 999, 999]), array([8.2, 8.2, 8.2, 8.2, 8.2, 8.2]), array([0.])]
#
# Normalized value holder:
# [array([7.3, 7.3, 7.3]), array([9.1, 9.1, 9.1, 9.1, 9.1, 9.1]), array([1.])]
#
# Derivative value holder:
# [array([999, 999, 999]), array([0., 0., 0., 0., 0., 0.]), array([1.])]
# Output neuron error holder:
# [array([4.6])]
#
# Output neuron out_minus_target error holder:
# [array([3.7])]
#
#
#
# synaptic weights starting random values ****************:
#
# Weights holder:  [array([999, 999, 999]), array([[0.94361564, 0.73412622, 0.41378177],
#        [0.97850434, 0.01474545, 0.73027366],
#        [0.59925636, 0.96945344, 0.78151866],
#        [0.23273011, 0.83903569, 0.10063323],
#        [0.52737497, 0.03831846, 0.61428659],
#        [0.96128135, 0.50637904, 0.13681026]]), array([[0.63238175, 0.49235124, 0.94056071, 0.95752905, 0.38554488,
#         0.41267111]])]
# None
#
# synaptic weights after training ****************:
#
# Weights holder:  [array([999, 999, 999]), array([[-2.09902782,  4.81588481, -1.29604935],
#        [ 2.63264692, -0.88962973, -1.02175568],
#        [ 3.57550922,  3.50279235,  2.22658815],
#        [ 2.81777909,  2.4598902 , -8.64644242],
#        [-2.1193812 , -1.1084624 , -0.8734155 ],
#        [ 3.89720814, -1.0756901 , -1.40310032]]), array([[-7.5141843 , -5.54154381,  9.99471258,  6.76601474, -6.34716585,
#         -6.26662609]])]
# None
#
# All matrixes **************** Start:
#
#
#
#
# weights holder:
# [   array([999, 999, 999]),
#     array([[-2.09902782,  4.81588481, -1.29604935],
#        [ 2.63264692, -0.88962973, -1.02175568],
#        [ 3.57550922,  3.50279235,  2.22658815],
#        [ 2.81777909,  2.4598902 , -8.64644242],
#        [-2.1193812 , -1.1084624 , -0.8734155 ],
#        [ 3.89720814, -1.0756901 , -1.40310032]]),
#     array([[-7.5141843 , -5.54154381,  9.99471258,  6.76601474, -6.34716585,
#         -6.26662609]])]
#
# Value holder:
# [   array([999, 999, 999]),
#     array([ 1.34423261,  0.71573255,  9.083764  , -3.32599657, -4.00814929,
#         1.40080624]),
#     array([-4.59495691])]
#
# Normalized value holder:
# [   array([0.98, 0.97, 0.98]),
#     array([0.79318513, 0.6716666 , 0.99988652, 0.03469004, 0.01784284,
#        0.8023118 ]),
#     array([0.01000161])]
#
# Derivative value holder:
# [array([999, 999, 999]), array([1.64042479e-01, 2.20530577e-01, 1.13467855e-04, 3.34866433e-02,
#        1.75244686e-02, 1.58607578e-01]), array([0.00990158])]
# Output neuron error holder:
# [1.3012461218493065e-12]
#
# Output neuron out_minus_target error holder:
# [1.6132241765168948e-06]
#
#
#
# None
# All matrixes **************** End:
#
# Namespace(input_config_file='logical_xor3.configuration.yaml')
# In calculate ****************
#
# neural_network descrition start ****************
#
# Description: 'The initial test set uses binary data. The data set is for Supervised
#     Learning, the machine should tune itself to find a specific pattern. The input
#     values are supposed to represent the values zero and one, although a machine can
#     be trained better with fuzzy values which are not a One or a zero.
#
#     Values which are close to "0" reprent a zero Values which are close to "1" represent
#     a one.'
# The data file format: input_1   input_2   input_3   output_1
# machine_dump_file_name: logical_xor3.trained.machine.bin
# training_data:
#     number_of_hidden_layers: 1
#     number_of_hidden_neurons: 6
#     number_of_input_neurons: 3
#     number_of_outputs_neurons: 1
#     number_of_training_iterations: 100000
#     training_data_file_name: logical_xor3.data.train.cvs
# validation_data: logical_xor3.data.validate.cvs
#
# <nr_lib.nr_1_hidden_layer.NeuralNetwork object at 0x7fe1c01822d0>
#
#  neural_network description end   ****************
#
# test data: ****************
# [[0.04 0.03 0.03]
#  [0.2 0.12 1.2]
#  [0.12 0.93 0.06]
#  [0.1 1.08 0.96]
#  [0.95 0.1 0.06]
#  [1.03 0.08 1.1]
#  [1.05 1.02 0.09]
#  [1.99 0.95 0.98]]
# Do calculaton with the trained network ****************
#
# Considering new situation [0.04 0.03 0.03] ->  [0.02180683]
# Considering new situation [0.2 0.12 1.2] ->  [0.97959546]
# Considering new situation [0.12 0.93 0.06] ->  [0.94789897]
# Considering new situation [0.1 1.08 0.96] ->  [0.62623983]
# Considering new situation [0.95 0.1 0.06] ->  [0.94953533]
# Considering new situation [1.03 0.08 1.1] ->  [0.30419187]
# Considering new situation [1.05 1.02 0.09] ->  [0.23930405]
# Considering new situation [1.99 0.95 0.98] ->  [0.21000924]
