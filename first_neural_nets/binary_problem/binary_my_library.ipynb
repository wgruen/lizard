# %% [markdown]
# # run locial problems with the libray I wrote

# %%
# !wget -O mount_gdrive.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb

# !ls
#!cat mount_gdrive.ipynb
# %run mount_gdrive.ipynb
# Out:
# --2022-01-05 02:45:18--  https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5034 (4.9K) [text/plain]
# Saving to: ‘mount_gdrive.ipynb’
#
# mount_gdrive.ipynb  100%[===================>]   4.92K  --.-KB/s    in 0s
#
# 2022-01-05 02:45:18 (40.0 MB/s) - ‘mount_gdrive.ipynb’ saved [5034/5034]
#
# mount_gdrive.ipynb  sample_data
# Mounted at /content/drive
# drive  mount_gdrive.ipynb  sample_data
# /content
# physical devises
# []
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime
# Not connected to a GPU

# %%
# run python code
import tensorflow as tf
import keras

# %cd "/content/drive/MyDrive/colab_wolfs_git_clones/lizard"
# !ls 
# !pwd

# %cd "first_neural_nets/binary_problem"
# !ls
# !pwd

# !pip install reportlab
# %run train_machine.py -i logical_or.configuration.yaml
# %run run_machine.py -i logical_or.configuration.yaml
# Out:
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# diff.log	   mount_gdrive.ipynb  picture_problem	statistical_analysis
# first_neural_nets  nmf		       README.md
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# binary_my_library.ipynb        logical_or.data.train.cvs       __pycache__
# binary_problem.py	       logical_or.data.validate.cvs    README.md
# example_2.data.validate.cvs    logical_or.trained.machine.bin  run_machine.py
# logical_or.configuration.yaml  output			       train_machine.py
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# Collecting reportlab
#   Downloading reportlab-3.6.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 8.5 MB/s
# Requirement already satisfied: pillow>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from reportlab) (7.1.2)
# Installing collected packages: reportlab
# Successfully installed reportlab-3.6.5
# pwd: /content/drive/My Drive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# Namespace(input_config_file='logical_or.configuration.yaml')
# Input file name: logical_or.data.train.cvs
# Raw training_set_inputs: ****************
# [[0.04 0.03 0.1  0.02]
#  [0.04 0.89 0.1  0.94]
#  [0.97 0.98 0.3  0.97]
#  [0.98 0.04 0.94 0.96]
#  [0.09 0.93 0.95 0.98]]
# training_set_inputs: ****************
# [[0.04 0.03 0.1 ]
#  [0.04 0.89 0.1 ]
#  [0.97 0.98 0.3 ]
#  [0.98 0.04 0.94]
#  [0.09 0.93 0.95]]
# training_set_outputs: ****************
# [[0.02]
#  [0.94]
#  [0.97]
#  [0.96]
#  [0.98]]
#
#
#
#
# weights holder:
# [   array([999, 999, 999]),
#     array([[0.68606648, 0.32322651, 0.55498328],
#        [0.61806079, 0.98217595, 0.85414492],
#        [0.48404163, 0.41253435, 0.49989678],
#        [0.50874712, 0.77984087, 0.72453145]]),
#     array([[0.15019612, 0.70538403, 0.65750911, 0.32137758]])]
#
# Value holder:
# [array([999, 999, 999]), array([8.2, 8.2, 8.2, 8.2]), array([0.])]
#
# Normalized value holder:
# [array([7.3, 7.3, 7.3]), array([9.1, 9.1, 9.1, 9.1]), array([1.])]
#
# Derivative value holder:
# [array([999, 999, 999]), array([0., 0., 0., 0.]), array([1.])]
# Output neuron error holder:
# [array([4.6])]
#
# Output neuron out_minus_target error holder:
# [array([3.7])]
#
#
#
# synaptic weights starting random values ****************:
#
# Weights holder:  [array([999, 999, 999]), array([[0.68606648, 0.32322651, 0.55498328],
#        [0.61806079, 0.98217595, 0.85414492],
#        [0.48404163, 0.41253435, 0.49989678],
#        [0.50874712, 0.77984087, 0.72453145]]), array([[0.15019612, 0.70538403, 0.65750911, 0.32137758]])]
# None
#
# synaptic weights after training ****************:
#
# Weights holder:  [array([999, 999, 999]), array([[-1.99036132, -3.15490273, -1.47167426],
#        [ 1.49704193,  2.46807108,  1.41430854],
#        [ 1.0873745 ,  1.61436122,  1.40140397],
#        [ 0.94304605,  1.60883118,  1.43387573]]), array([[-14.31367193,   2.28438692,   0.79242621,   0.79367388]])]
# None
#
# All matrixes **************** Start:
#
#
#
#
# weights holder:
# [   array([999, 999, 999]),
#     array([[-1.99036132, -3.15490273, -1.47167426],
#        [ 1.49704193,  2.46807108,  1.41430854],
#        [ 1.0873745 ,  1.61436122,  1.40140397],
#        [ 0.94304605,  1.60883118,  1.43387573]]),
#     array([[-14.31367193,   2.28438692,   0.79242621,   0.79367388]])]
#
# Value holder:
# [   array([999, 999, 999]),
#     array([-4.51125738,  3.77362477,  2.93054716,  2.94326289]),
#     array([3.58354317])]
#
# Normalized value holder:
# [   array([0.09, 0.93, 0.95]),
#     array([0.01086529, 0.97754706, 0.949336  , 0.94994411]),
#     array([0.97297361])]
#
# Derivative value holder:
# [array([999, 999, 999]), array([0.01074723, 0.02194881, 0.04809716, 0.0475503 ]), array([0.02629596])]
# Output neuron error holder:
# [2.468507668238726e-05]
#
# Output neuron out_minus_target error holder:
# [-0.007026389781728204]
#
#
#
# None
# All matrixes **************** End:
#
# Namespace(input_config_file='logical_or.configuration.yaml')
# In calculate ****************
#
# neural_network descrition start ****************
#
# Description: 'The initial test set uses binary data. The data set is for Supervised
#     Learning, the machine should tune itself to find a specific pattern. The input
#     values are supposed to represent the values zero and one, although a machine can
#     be trained better with fuzzy values which are not a One or a zero.
#
#     Values which are close to "0" reprent a zero Values which are close to "1" represent
#     a one.'
# The data file format: input_1   input_2   input_3   output_1
# machine_dump_file_name: logical_or.trained.machine.bin
# training_data:
#     number_of_hidden_layers: 1
#     number_of_hidden_neurons: 4
#     number_of_input_neurons: 3
#     number_of_outputs_neurons: 1
#     number_of_training_iterations: 100000
#     training_data_file_name: logical_or.data.train.cvs
# validation_data: logical_or.data.validate.cvs
#
# <nr_lib.nr_1_hidden_layer.NeuralNetwork object at 0x7f2b85f94c50>
#
#  neural_network description end   ****************
#
# test data: ****************
# [[0.04 0.06 0.03]
#  [0.2 0.12 1.2]
#  [0.12 0.93 0.06]
#  [0.1 1.08 0.96]
#  [0.89 0.1 0.06]
#  [1.03 0.08 1.1]
#  [1.05 1.02 0.09]
#  [1.03 0.95 0.91]]
# Do calculaton with the trained network ****************
#
# Considering new situation [0.04 0.06 0.03] ->  [0.01989826]
# Considering new situation [0.2 0.12 1.2] ->  [0.9201055]
# Considering new situation [0.12 0.93 0.06] ->  [0.94950896]
# Considering new situation [0.1 1.08 0.96] ->  [0.97539487]
# Considering new situation [0.89 0.1 0.06] ->  [0.84090277]
# Considering new situation [1.03 0.08 1.1] ->  [0.9681346]
# Considering new situation [1.05 1.02 0.09] ->  [0.97557609]
# Considering new situation [1.03 0.95 0.91] ->  [0.97813975]
