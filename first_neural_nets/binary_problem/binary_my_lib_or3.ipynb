# %% [markdown]
# # run logical problems with the libray I wrote

# %%
# !wget -O mount_gdrive.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb

# !ls
#!cat mount_gdrive.ipynb
# %run mount_gdrive.ipynb
# Out:
# --2022-01-17 14:22:42--  https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10889 (11K) [text/plain]
# Saving to: ‘mount_gdrive.ipynb’
#
# mount_gdrive.ipynb  100%[===================>]  10.63K  --.-KB/s    in 0s
#
# 2022-01-17 14:22:42 (44.6 MB/s) - ‘mount_gdrive.ipynb’ saved [10889/10889]
#
# mount_gdrive.ipynb  sample_data
# Mounted at /content/drive
# drive  mount_gdrive.ipynb  sample_data
# /content
# physical devises
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Mon Jan 17 14:23:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    28W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
# run python code
exit()  # exit runtime, so it restarts the runtime session


# !wget -O get_gpu.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/get_gpu.ipynb

#!ls
#!cat mount_gdrive.ipynb
# %run get_gpu.ipynb

# how to ensrue a GPU is usd by tf?
#tf. config. list_physical_devices('GPU')

# %cd "/content/drive/MyDrive/colab_wolfs_git_clones/lizard"
# !ls 
# !pwd

# %cd "first_neural_nets/binary_problem"
# !ls
# !pwd

# !pip install reportlab
# %run train_machine.py -i logical_or3.configuration.yaml
# %run run_machine.py -i logical_or3.configuration.yaml
# Out:
# --2022-01-17 14:23:05--  https://raw.githubusercontent.com/wgruen/lizard/master/get_gpu.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10864 (11K) [text/plain]
# Saving to: ‘get_gpu.ipynb’
#
# get_gpu.ipynb       100%[===================>]  10.61K  --.-KB/s    in 0s
#
# 2022-01-17 14:23:05 (59.1 MB/s) - ‘get_gpu.ipynb’ saved [10864/10864]
#
# physical devises
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Mon Jan 17 14:23:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    28W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Found GPU at: /device:GPU:0
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# diff.log	   get_tpu.ipynb       picture_problem
# first_neural_nets  mount_gdrive.ipynb  README.md
# get_gpu.ipynb	   nmf		       statistical_analysis
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# binary_my_lib_or3.ipynb		 logical_xor3.data.train.cvs
# binary_my_lib_xor3.ipynb	 logical_xor3.data.validate.cvs
# binary_problem.py		 logical_xor3.trained.machine.bin
# logical_or2.data.validate.cvs	 output
# logical_or3.configuration.yaml	 __pycache__
# logical_or3.data.train.cvs	 README.md
# logical_or3.data.validate.cvs	 run_machine.py
# logical_or.trained.machine.bin	 train_machine.py
# logical_xor3.configuration.yaml
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# Collecting reportlab
#   Downloading reportlab-3.6.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 12.0 MB/s
# Requirement already satisfied: pillow>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from reportlab) (7.1.2)
# Installing collected packages: reportlab
# Successfully installed reportlab-3.6.5
# pwd: /content/drive/My Drive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem
# Namespace(input_config_file='logical_or3.configuration.yaml')
# Input file name: logical_or3.data.train.cvs
# Raw training_set_inputs: ****************
# [[0.04 0.03 0.1  0.02]
#  [0.04 0.89 0.1  0.94]
#  [0.97 0.98 0.3  0.97]
#  [0.98 0.04 0.94 0.96]
#  [0.09 0.93 0.95 0.98]]
# training_set_inputs: ****************
# [[0.04 0.03 0.1 ]
#  [0.04 0.89 0.1 ]
#  [0.97 0.98 0.3 ]
#  [0.98 0.04 0.94]
#  [0.09 0.93 0.95]]
# training_set_outputs: ****************
# [[0.02]
#  [0.94]
#  [0.97]
#  [0.96]
#  [0.98]]
#
#
#
#
# weights holder:
# [   array([999, 999, 999]),
#     array([[0.36607394, 0.42989044, 0.72377068],
#        [0.44052889, 0.03159571, 0.17874551],
#        [0.55137297, 0.43147522, 0.15165936],
#        [0.89073592, 0.25582087, 0.90536944]]),
#     array([[0.43602043, 0.71068165, 0.43037754, 0.48356469]])]
#
# Value holder:
# [array([999, 999, 999]), array([8.2, 8.2, 8.2, 8.2]), array([0.])]
#
# Normalized value holder:
# [array([7.3, 7.3, 7.3]), array([9.1, 9.1, 9.1, 9.1]), array([1.])]
#
# Derivative value holder:
# [array([999, 999, 999]), array([0., 0., 0., 0.]), array([1.])]
# Output neuron error holder:
# [array([4.6])]
#
# Output neuron out_minus_target error holder:
# [array([3.7])]
#
#
#
# synaptic weights starting random values ****************:
#
# Weights holder:  [array([999, 999, 999]), array([[0.36607394, 0.42989044, 0.72377068],
#        [0.44052889, 0.03159571, 0.17874551],
#        [0.55137297, 0.43147522, 0.15165936],
#        [0.89073592, 0.25582087, 0.90536944]]), array([[0.43602043, 0.71068165, 0.43037754, 0.48356469]])]
# None
#
# synaptic weights after training ****************:
#
# Weights holder:  [array([999, 999, 999]), array([[ 1.41511789,  2.28012754,  1.30671013],
#        [-2.12164809, -3.06570502, -1.00009431],
#        [ 0.90417352,  0.28996706, -1.09894165],
#        [ 1.76684284,  2.52298506,  1.13752124]]), array([[  2.12284824, -13.3867715 ,  -1.73845174,   2.69610938]])]
# None
#
# All matrixes **************** Start:
#
#
#
#
# weights holder:
# [   array([999, 999, 999]),
#     array([[ 1.41511789,  2.28012754,  1.30671013],
#        [-2.12164809, -3.06570502, -1.00009431],
#        [ 0.90417352,  0.28996706, -1.09894165],
#        [ 1.76684284,  2.52298506,  1.13752124]]),
#     array([[  2.12284824, -13.3867715 ,  -1.73845174,   2.69610938]])]
#
# Value holder:
# [   array([999, 999, 999]),
#     array([ 3.48925318, -3.99214099, -0.69294536,  3.58603637]),
#     array([3.86117348])]
#
# Normalized value holder:
# [   array([0.09, 0.93, 0.95]),
#     array([0.97038044, 0.01812555, 0.33337818, 0.97303909]),
#     array([0.9793904])]
#
# Derivative value holder:
# [array([999, 999, 999]), array([0.02874224, 0.01779701, 0.22223717, 0.02623402]), array([0.02018484])]
# Output neuron error holder:
# [1.8580454780010374e-07]
#
# Output neuron out_minus_target error holder:
# [-0.000609597486543545]
#
#
#
# None
# All matrixes **************** End:
#
# Namespace(input_config_file='logical_or3.configuration.yaml')
# In calculate ****************
#
# neural_network descrition start ****************
#
# Description: 'The initial test set uses binary data. The data set is for Supervised
#     Learning, the machine should tune itself to find a specific pattern. The input
#     values are supposed to represent the values zero and one, although a machine can
#     be trained better with fuzzy values which are not a One or a zero.
#
#     Values which are close to "0" reprent a zero Values which are close to "1" represent
#     a one.'
# The data file format: input_1   input_2   input_3   output_1
# machine_dump_file_name: logical_or3.trained.machine.bin
# training_data:
#     number_of_hidden_layers: 1
#     number_of_hidden_neurons: 4
#     number_of_input_neurons: 3
#     number_of_outputs_neurons: 1
#     number_of_training_iterations: 100000
#     training_data_file_name: logical_or3.data.train.cvs
# validation_data: logical_or3.data.validate.cvs
#
# <nr_lib.nr_1_hidden_layer.NeuralNetwork object at 0x7f8860542610>
#
#  neural_network description end   ****************
#
# test data: ****************
# [[0.04 0.06 0.03]
#  [0.2 0.12 1.2]
#  [0.12 0.93 0.06]
#  [0.1 1.08 0.96]
#  [0.89 0.1 0.06]
#  [1.03 0.08 1.1]
#  [1.05 1.02 0.09]
#  [1.03 0.95 0.91]]
# Do calculaton with the trained network ****************
#
# Considering new situation [0.04 0.06 0.03] ->  [0.02033634]
# Considering new situation [0.2 0.12 1.2] ->  [0.9035453]
# Considering new situation [0.12 0.93 0.06] ->  [0.94832611]
# Considering new situation [0.1 1.08 0.96] ->  [0.98167559]
# Considering new situation [0.89 0.1 0.06] ->  [0.83766142]
# Considering new situation [1.03 0.08 1.1] ->  [0.97031111]
# Considering new situation [1.05 1.02 0.09] ->  [0.96683571]
# Considering new situation [1.03 0.95 0.91] ->  [0.97803727]
