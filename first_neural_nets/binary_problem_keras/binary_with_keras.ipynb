# %% [markdown]
# # run binary with keras

# %%
from google.colab import drive
import tensorflow as tf
import keras

drive.mount('/content/drive')
# !ls
# !pwd

physical_devices = tf.config.list_physical_devices('GPU')
print("physical devises")
print(physical_devices)

print("tensorflow version")
print(tf.__version__)
print("keras version")
print(keras.__version__)
# Out:
# Mounted at /content/drive
# drive  sample_data
# /content
# physical devises
# []
# tensorflow version
# 2.7.0
# keras version
# 2.7.0

# %%
# run python code
import tensorflow as tf
import keras

# %cd "/content/drive/MyDrive/colab_wolfs_git_clones/lizard"
# !ls 
# !pwd

# %cd "first_neural_nets/binary_problem_keras"
# !ls
# !pwd

# !pip install reportlab
# %run train_machine.py -i logical_xor3_v3.configuration.keras.yaml
# Out:
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# first_neural_nets  nmf	picture_problem  README.md  statistical_analysis
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem_keras
# binary_with_keras.ipynb			  logs
# binary_with_keras.py			  output
# data					  predict_machine.py
# logical_or.configuration.keras.yaml	  __pycache__
# logical_xor2.configuration.keras.yaml	  README.md
# logical_xor3.configuration.keras.yaml	  saved_machines
# logical_xor3_v2.configuration.keras.yaml  train_machine.py
# logical_xor3_v3.configuration.keras.yaml  validate_machine.py
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem_keras
# ...
# Description: 'The model was trained with the dataset "training_data_embedded_v2" I
#   cahnged the learning rate from 0.001 to.0.01
#
#   The 1st hidden layer with 6 nodes and the 2nd hidden layer with 3 nodes The 1st
# ...
