# %% [markdown]
# # mount to Google Drive
#
# ---

# %%
# !wget -O mount_gdrive.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb

# !ls
# %run mount_gdrive.ipynb
# Out:
# --2022-01-20 03:17:09--  https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10889 (11K) [text/plain]
# Saving to: ‘mount_gdrive.ipynb’
#
# mount_gdrive.ipynb  100%[===================>]  10.63K  --.-KB/s    in 0s
#
# 2022-01-20 03:17:09 (53.4 MB/s) - ‘mount_gdrive.ipynb’ saved [10889/10889]
#
# mount_gdrive.ipynb  sample_data
# Mounted at /content/drive
# drive  mount_gdrive.ipynb  sample_data
# /content
# physical devises
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Thu Jan 20 03:17:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %% [markdown]
# # Overview of the results
#
#
# ---

# %% [markdown]
# ## Training Data
#      training_data_embedded: [
#         [0.04,  0.03,  0.01],
#         [0.04,  0.96,  0.99],
#         [0.98,  0.02,  0.99],
#         [0.96,  0.97,  0.01]
#      ]

# %% [markdown]
# ###  machine fitting
#
# The hyper parameters for each run were number of hidden neurons and learning rate. Some previous experiments had suggested to leave the batch size at 32, and have no second hidden layer.
#
# Also I didn't use early stopping and let machines run 100 000 epochs. With the very small training set, this worked best
#
# The learning rate was adjusted once only, after 10 000 epocchs, when it would be divided by 10.
#
#
# The machine with four hidden neurons always had a very low error. Sometimes the machine with two hidden neurons would get a low error.

# %% [markdown]
# # Predict with the machine
#
# ---

# %%
# run python code
# %cd
# %cd "/content/drive/MyDrive/colab_wolfs_git_clones/lizard"
#!ls 
#!pwd

# %cd "first_neural_nets/binary_problem_keras"
#!ls
#!pwd

# !pip install reportlab
# %run predict_machine.py -i config/logical_xor2.configuration.keras.yaml
# Out:
# /root
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem_keras
# Collecting reportlab
#   Downloading reportlab-3.6.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 8.0 MB/s
# Requirement already satisfied: pillow>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from reportlab) (7.1.2)
# Installing collected packages: reportlab
# Successfully installed reportlab-3.6.5
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin
#
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin
#
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.0001--bs-4.bin
#
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.01--bs-4.bin
#
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.001--bs-4.bin
#
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.0001--bs-4.bin
#
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.01--bs-4.bin
#
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.001--bs-4.bin
#
# not connected to a TPU
# === can't load machine - the file is not available
# saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.0001--bs-4.bin
#
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Train machine
#
#
# ---

# %%
# run python code
exit()  # exit runtime, so it restarts the runtime session


# !wget -O get_gpu.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/get_gpu.ipynb

#!ls
#!cat mount_gdrive.ipynb
# %run get_gpu.ipynb

# how to ensrue a GPU is usd by tf?
#tf. config. list_physical_devices('GPU') 

# %cd
# %cd "/content/drive/MyDrive/colab_wolfs_git_clones/lizard"
#!ls 
#!pwd

# %cd "first_neural_nets/binary_problem_keras"
#!ls
#!pwd

# !pip install reportlab
# %run train_machine.py -i config/logical_xor2.configuration.keras.yaml
# Out:
# --2022-01-20 03:17:41--  https://raw.githubusercontent.com/wgruen/lizard/master/get_gpu.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10864 (11K) [text/plain]
# Saving to: ‘get_gpu.ipynb’
#
# get_gpu.ipynb       100%[===================>]  10.61K  --.-KB/s    in 0.001s
#
# 2022-01-20 03:17:41 (18.0 MB/s) - ‘get_gpu.ipynb’ saved [10864/10864]
#
# physical devises
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Thu Jan 20 03:17:42 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    26W /  70W |    266MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Found GPU at: /device:GPU:0
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime
# /root
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/first_neural_nets/binary_problem_keras
# Requirement already satisfied: reportlab in /usr/local/lib/python3.7/dist-packages (3.6.5)
# Requirement already satisfied: pillow>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from reportlab) (7.1.2)
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
#                                                                 machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478      0.9  0.259569
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
#                                                                  machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0   saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478     0.90  0.259569
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin  100000  0.000372                        0.000310  0.0  0.003073                            0.001189     0.85  0.494197
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
#                                                                   machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0    saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478     0.90  0.259569
# 0   saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin  100000  0.000372                        0.000310  0.0  0.003073                            0.001189     0.85  0.494197
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.0001--bs-4.bin  100000  0.073082                        0.035041  0.0  0.090655                            0.042353     0.85  3.312100
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 3)                 9
#
#  dense_1 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________
#                                                                   machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0    saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478    0.900  0.259569
# 0   saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin  100000  0.000372                        0.000310  0.0  0.003073                            0.001189    0.850  0.494197
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.0001--bs-4.bin  100000  0.073082                        0.035041  0.0  0.090655                            0.042353    0.850  3.312100
# 0    saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.01--bs-4.bin   23663  0.160069                        0.078861  0.0  0.166355                            0.082695    0.625  4.060369
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 3)                 9
#
#  dense_1 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f8069539b90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#                                                                   machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0    saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478    0.900  0.259569
# 0   saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin  100000  0.000372                        0.000310  0.0  0.003073                            0.001189    0.850  0.494197
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.0001--bs-4.bin  100000  0.073082                        0.035041  0.0  0.090655                            0.042353    0.850  3.312100
# 0    saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.01--bs-4.bin   23663  0.160069                        0.078861  0.0  0.166355                            0.082695    0.625  4.060369
# 0   saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.001--bs-4.bin  100000  0.000232                        0.000182  0.0  0.003283                            0.001126    0.850  0.453510
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 3)                 9
#
#  dense_1 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f80692fe9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#                                                                   machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0    saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478    0.900  0.259569
# 0   saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin  100000  0.000372                        0.000310  0.0  0.003073                            0.001189    0.850  0.494197
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.0001--bs-4.bin  100000  0.073082                        0.035041  0.0  0.090655                            0.042353    0.850  3.312100
# 0    saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.01--bs-4.bin   23663  0.160069                        0.078861  0.0  0.166355                            0.082695    0.625  4.060369
# 0   saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.001--bs-4.bin  100000  0.000232                        0.000182  0.0  0.003283                            0.001126    0.850  0.453510
# 0  saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.0001--bs-4.bin  100000  0.013439                        0.009295  0.0  0.022588                            0.012815    0.800  1.711539
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 12
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________
#                                                                   machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0    saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478    0.900  0.259569
# 0   saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin  100000  0.000372                        0.000310  0.0  0.003073                            0.001189    0.850  0.494197
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.0001--bs-4.bin  100000  0.073082                        0.035041  0.0  0.090655                            0.042353    0.850  3.312100
# 0    saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.01--bs-4.bin   23663  0.160069                        0.078861  0.0  0.166355                            0.082695    0.625  4.060369
# 0   saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.001--bs-4.bin  100000  0.000232                        0.000182  0.0  0.003283                            0.001126    0.850  0.453510
# 0  saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.0001--bs-4.bin  100000  0.013439                        0.009295  0.0  0.022588                            0.012815    0.800  1.711539
# 0    saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.01--bs-4.bin   20272  0.240046                        0.118140  0.0  0.243692                            0.120067    0.500  5.923001
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 12
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________
#                                                                   machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0    saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478    0.900  0.259569
# 0   saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin  100000  0.000372                        0.000310  0.0  0.003073                            0.001189    0.850  0.494197
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.0001--bs-4.bin  100000  0.073082                        0.035041  0.0  0.090655                            0.042353    0.850  3.312100
# 0    saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.01--bs-4.bin   23663  0.160069                        0.078861  0.0  0.166355                            0.082695    0.625  4.060369
# 0   saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.001--bs-4.bin  100000  0.000232                        0.000182  0.0  0.003283                            0.001126    0.850  0.453510
# 0  saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.0001--bs-4.bin  100000  0.013439                        0.009295  0.0  0.022588                            0.012815    0.800  1.711539
# 0    saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.01--bs-4.bin   20272  0.240046                        0.118140  0.0  0.243692                            0.120067    0.500  5.923001
# 0   saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.001--bs-4.bin  100000  0.000321                        0.000270  0.0  0.002924                            0.001110    0.800  0.475487
# not connected to a TPU
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 12
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________
#                                                                   machine  epochs      loss  mean_squared_logarithmic_error  auc  val_loss  val_mean_squared_logarithmic_error  val_auc   predict
# 0    saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.01--bs-4.bin  100000  0.000004                        0.000004  0.0  0.001671                            0.000478    0.900  0.259569
# 0   saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.001--bs-4.bin  100000  0.000372                        0.000310  0.0  0.003073                            0.001189    0.850  0.494197
# 0  saved_machines/xor2--ep-100000--i-2--hl1-2--hl2-0--lr-0.0001--bs-4.bin  100000  0.073082                        0.035041  0.0  0.090655                            0.042353    0.850  3.312100
# 0    saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.01--bs-4.bin   23663  0.160069                        0.078861  0.0  0.166355                            0.082695    0.625  4.060369
# 0   saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.001--bs-4.bin  100000  0.000232                        0.000182  0.0  0.003283                            0.001126    0.850  0.453510
# 0  saved_machines/xor2--ep-100000--i-2--hl1-3--hl2-0--lr-0.0001--bs-4.bin  100000  0.013439                        0.009295  0.0  0.022588                            0.012815    0.800  1.711539
# 0    saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.01--bs-4.bin   20272  0.240046                        0.118140  0.0  0.243692                            0.120067    0.500  5.923001
# 0   saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.001--bs-4.bin  100000  0.000321                        0.000270  0.0  0.002924                            0.001110    0.800  0.475487
# 0  saved_machines/xor2--ep-100000--i-2--hl1-4--hl2-0--lr-0.0001--bs-4.bin  100000  0.161505                        0.079962  0.0  0.167915                            0.083512    0.625  4.315562
