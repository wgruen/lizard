# %% [markdown]
# # mount to Google Drive
#
# ---

# %%
# !wget -O mount_gdrive.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb

#!ls
# %run mount_gdrive.ipynb
# Out:
# --2022-01-29 17:24:46--  https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10889 (11K) [text/plain]
# Saving to: ‘mount_gdrive.ipynb’
#
# mount_gdrive.ipynb  100%[===================>]  10.63K  --.-KB/s    in 0s
#
# 2022-01-29 17:24:46 (80.4 MB/s) - ‘mount_gdrive.ipynb’ saved [10889/10889]
#
# Mounted at /content/drive
# drive  mount_gdrive.ipynb  sample_data
# /content
# physical devises
# []
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Not connected to a GPU
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %% [markdown]
# # Run the machine

# %% [markdown]
# This code takes data from a CSV file, and then uses the "mean" method to find the outliers.
#
# For each data set, pdf file with the results are created and saved in the directory called output.

# %%
# run python code
# %cd "/content/drive/MyDrive/colab_wolfs_git_clones/lizard"
# !ls 
# !pwd

# %cd "statistical_analysis/standard_dev"
# !ls
# !pwd

# !pip install reportlab
# %run standard_deviation_analyze_tp.py -i configuration.yaml
# Out:
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# diff.log	   get_tpu.ipynb       picture_problem
# first_neural_nets  mount_gdrive.ipynb  README.md
# get_gpu.ipynb	   nmf		       statistical_analysis
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/statistical_analysis/standard_dev
# configuration.yaml			    standard_deviation_analyze_tp.ipynb
# mount_gdrive.ipynb			    standard_deviation_analyze_tp.py
# output					    standard_deviation_basic_example.py
# standard_deviation_analyze_tp_individal.py  standard_deviation_example_tp.ipynb
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/statistical_analysis/standard_dev
# ...
# args:  Namespace(input_config_file='configuration.yaml')
# Description: The test is about analysing a file or files in a direcotry, then creating
#   pdf files read_file_or_dir "../data/D1-150.csv" read_file_or_dir "../data/"
# cutoff_offset_percent: 25
# read_file_or_dir: ../data/D1-150.csv
#
# ...
