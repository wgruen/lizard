# %% [markdown]
# # Connect colab to Google Drive

# %%
# !wget -O mount_gdrive.ipynb https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb

#!ls
# %run mount_gdrive.ipynb
# Out:
# --2022-01-29 17:29:56--  https://raw.githubusercontent.com/wgruen/lizard/master/mount_gdrive.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10889 (11K) [text/plain]
# Saving to: ‘mount_gdrive.ipynb’
#
# mount_gdrive.ipynb  100%[===================>]  10.63K  --.-KB/s    in 0.001s
#
# 2022-01-29 17:29:56 (7.42 MB/s) - ‘mount_gdrive.ipynb’ saved [10889/10889]
#
# Mounted at /content/drive
# drive  mount_gdrive.ipynb  sample_data
# /content
# physical devises
# []
# tensorflow version
# 2.7.0
# keras version
# 2.7.0
# Not connected to a GPU
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
from google.colab import drive
import tensorflow as tf
from tensorflow import keras as keras

drive.mount('/content/drive')
# !ls
# !pwd

physical_devices = tf.config.list_physical_devices('GPU')
print("physical devises")
print(physical_devices)

print("tensorflow version")
print(tf.__version__)
print("keras version")
print(keras.__version__)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# drive  mount_gdrive.ipynb  sample_data
# /content
# physical devises
# []
# tensorflow version
# 2.7.0
# keras version
# 2.7.0

# %% [markdown]
# # Run the machine

# %% [markdown]
# KMeansThis code takes data from a CSV file, and then uses the **"KMeans"** method to find the outliers.

# %%
# run python code
import tensorflow as tf
from tensorflow import keras as keras

# %cd "/content/drive/MyDrive/colab_wolfs_git_clones/lizard"
# !ls 
# !pwd

# %cd "statistical_analysis/k-means/"
# !ls
# !pwd

# !pip install reportlab
# %run k-means_analyze_tp_2nd.py -i configuration.yaml
# Out:
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# diff.log	   get_tpu.ipynb       picture_problem
# first_neural_nets  mount_gdrive.ipynb  README.md
# get_gpu.ipynb	   nmf		       statistical_analysis
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/statistical_analysis/k-means
# configuration.yaml	   k-means_analyze_tp.py     k_means_example.ipynb
# k-means_analyze_tp_2nd.py  k-means_basic_example.py  k_means.ipynb
# /content/drive/MyDrive/colab_wolfs_git_clones/lizard/statistical_analysis/k-means
# ...
#      |████████████████████████████████| 2.8 MB 5.3 MB/s
# ...
# Description: 'The test is about analysing a file or files in a direcotry, then creating
#   pdf files read_file_or_dir "../data/D1-150.csv" read_file_or_dir "../data/"
#
#   The percentage offset for interquartile should be 25, since it is supposed to be
#   25 percent and 75 percent'
# cutoff_offset_percent: 25
# read_file_or_dir: ../data/
#
# D1-150.csv
# ...
